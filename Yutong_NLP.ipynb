# %% [markdown]
# <a href="https://colab.research.google.com/github/Yutong-Lu/CHL5230FinalProject/blob/main/Yutong_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import the pandas library and alias it as 'pd'
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

# Import the necessary libraries for data cleaning
import re  # Regular expressions library for text manipulation
from datetime import datetime  # Library for handling dates and times

# %%
# Read the data from a CSV file named "covid_vaccine.csv" into a DataFrame
df = pd.read_csv("diabetes NLP.csv", encoding='ISO-8859-1')

# Clean column names
df.columns = ['title', 'abstract', 'discussion']

# Display the first few rows (head) of the DataFrame to inspect the data
df.head()

# %%
# !pip install contractions
import contractions

# Expand contractions in the 'abstract' and 'discussion' columns
df['abstract_expanded'] = df['abstract'].apply(lambda x: contractions.fix(x))
df['discussion_expanded'] = df['discussion'].apply(lambda x: contractions.fix(x))

df.head()
# Out:
#                                                title  \
# 0  Predicting Type 2 Diabetes Using Logistic Regr...
# 1  Machine Learning Methods to Predict Diabetes C...
# 2  Predicting youth diabetes risk using NHANES da...
# 3  Accuracy of Machine Learning Classification Mo...
# 4  Cardiovascular complications in a diabetes pre...
#
#                                             abstract  \
# 0  Diabetes mellitus is one of the most common hu...
# 1  One of the areas where Artificial Intelligence...
# 2  Prediabetes and diabetes mellitus (preDM/DM) h...
# 3  Soft-computing and statistical learning models...
# 4  Prediction model has been the focus of studies...
#
#                                           discussion  \
# 0  Diabetes has become one of the leading causes ...
# 1  This work describes the application of a moder...
# 2  The recently increasing prevalence of preDM/DM...
# 3  4.1. Synopsis of Evidence\nIn recent years, in...
# 4  This review identified ten machine learning mo...
#
#                                    abstract_expanded  \
# 0  Diabetes mellitus is one of the most common hu...
# 1  One of the areas where Artificial Intelligence...
# 2  Prediabetes and diabetes mellitus (preDM/DM) h...
# 3  Soft-computing and statistical learning models...
# 4  Prediction model has been the focus of studies...
#
#                                  discussion_expanded
# 0  Diabetes has become one of the leading causes ...
# 1  This work describes the application of a moder...
# 2  The recently increasing prevalence of preDM/DM...
# 3  4.1. Synopsis of Evidence\nIn recent years, in...
# 4  This review identified ten machine learning mo...

# %%
# Let's perform some basic data cleaning tasks such as:
# - Lowercasing the texts
# - Removing URLs
# - Removing special characters and numbers

# Function to remove URLs
def remove_url(text):
    return re.sub(r'http\S+', '', text)

# Function to remove special characters and numbers
def remove_special_characters(text):
    return re.sub(r'[^A-Za-z\s]', '', text)

# Perform the data cleaning
df['title'] = df['title'].str.lower()

df['abstract'] = df['abstract_expanded'].str.lower()
df['abstract'] = df['abstract'].apply(remove_url)
df['abstract'] = df['abstract'].apply(remove_special_characters)

df['discussion'] = df['discussion_expanded'].str.lower()
df['discussion'] = df['discussion'].apply(remove_url)
df['discussion'] = df['discussion'].apply(remove_special_characters)

df.head()

# %% [markdown]
# Tokenization

# %%
# !pip install nltk
import nltk
from nltk.tokenize import word_tokenize

nltk.download('punkt')
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.1)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
def tokenize_text(text):
   return word_tokenize(text)

# %%
df['title_tokens'] = df['title'].apply(tokenize_text)
df['abstract_tokens'] = df['abstract'].apply(tokenize_text)
df['dicussion_tokens'] = df['discussion'].apply(tokenize_text)

df.head()
# Out:
#                                                title  \
# 0  predicting type 2 diabetes using logistic regr...
# 1  machine learning methods to predict diabetes c...
# 2  predicting youth diabetes risk using nhanes da...
# 3  accuracy of machine learning classification mo...
# 4  cardiovascular complications in a diabetes pre...
#
#                                             abstract  \
# 0  diabetes mellitus is one of the most common hu...
# 1  one of the areas where artificial intelligence...
# 2  prediabetes and diabetes mellitus predmdm have...
# 3  softcomputing and statistical learning models ...
# 4  prediction model has been the focus of studies...
#
#                                           discussion  \
# 0  diabetes has become one of the leading causes ...
# 1  this work describes the application of a moder...
# 2  the recently increasing prevalence of predmdm ...
# 3   synopsis of evidence\nin recent years informa...
# 4  this review identified ten machine learning mo...
#
#                                    abstract_expanded  \
# 0  Diabetes mellitus is one of the most common hu...
# 1  One of the areas where Artificial Intelligence...
# 2  Prediabetes and diabetes mellitus (preDM/DM) h...
# 3  Soft-computing and statistical learning models...
# 4  Prediction model has been the focus of studies...
#
#                                  discussion_expanded  \
# 0  Diabetes has become one of the leading causes ...
# 1  This work describes the application of a moder...
# 2  The recently increasing prevalence of preDM/DM...
# 3  4.1. Synopsis of Evidence\nIn recent years, in...
# 4  This review identified ten machine learning mo...
#
#                                         title_tokens  \
# 0  [predicting, type, 2, diabetes, using, logisti...
# 1  [machine, learning, methods, to, predict, diab...
# 2  [predicting, youth, diabetes, risk, using, nha...
# 3  [accuracy, of, machine, learning, classificati...
# 4  [cardiovascular, complications, in, a, diabete...
#
#                                      abstract_tokens  \
# 0  [diabetes, mellitus, is, one, of, the, most, c...
# 1  [one, of, the, areas, where, artificial, intel...
# 2  [prediabetes, and, diabetes, mellitus, predmdm...
# 3  [softcomputing, and, statistical, learning, mo...
# 4  [prediction, model, has, been, the, focus, of,...
#
#                                     dicussion_tokens
# 0  [diabetes, has, become, one, of, the, leading,...
# 1  [this, work, describes, the, application, of, ...
# 2  [the, recently, increasing, prevalence, of, pr...
# 3  [synopsis, of, evidence, in, recent, years, in...
# 4  [this, review, identified, ten, machine, learn...

# %% [markdown]
# Stop words

# %%
# Import the 'stopwords' corpus from the Natural Language Toolkit (NLTK)
from nltk.corpus import stopwords

# Download the set of stopwords from NLTK. This is necessary the first time you run this code.
nltk.download('stopwords')

# Define a function that removes stop words from a list of tokens.
# Stop words are common words that are usually filtered out in NLP tasks.
def remove_stop_words(tokens):
    # Create a set of English stop words. Sets are faster for membership tests than lists.
    stop_words_set = set(stopwords.words('english'))

    # Return a new list that contains only the tokens that are not stop words.
    # The token is also converted to lowercase to ensure case-insensitive matching.
    return [token for token in tokens if token.lower() not in stop_words_set]

# Apply the 'remove_stop_words' function to the 'tokens' column of the dataframe 'df'.
# The result is a new column 'tokens_no_stop' in the dataframe 'df'.
df['title_tokens_no_stop'] = df['title_tokens'].apply(remove_stop_words)
df['abstract_tokens_no_stop'] = df['abstract_tokens'].apply(remove_stop_words)
df['discussion_tokens_no_stop'] = df['dicussion_tokens'].apply(remove_stop_words)

# Display the first few rows of the DataFrame showing the 'tweet', 'tokens', and 'tokens_no_stop' columns.
# This gives a visual comparison between the original tokens and the tokens after stop words removal.
df[['title', 'title_tokens', 'title_tokens_no_stop']].head()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                                title  \
# 0  predicting type 2 diabetes using logistic regr...
# 1  machine learning methods to predict diabetes c...
# 2  predicting youth diabetes risk using nhanes da...
# 3  accuracy of machine learning classification mo...
# 4  cardiovascular complications in a diabetes pre...
#
#                                         title_tokens  \
# 0  [predicting, type, 2, diabetes, using, logisti...
# 1  [machine, learning, methods, to, predict, diab...
# 2  [predicting, youth, diabetes, risk, using, nha...
# 3  [accuracy, of, machine, learning, classificati...
# 4  [cardiovascular, complications, in, a, diabete...
#
#                                 title_tokens_no_stop
# 0  [predicting, type, 2, diabetes, using, logisti...
# 1  [machine, learning, methods, predict, diabetes...
# 2  [predicting, youth, diabetes, risk, using, nha...
# 3  [accuracy, machine, learning, classification, ...
# 4  [cardiovascular, complications, diabetes, pred...
